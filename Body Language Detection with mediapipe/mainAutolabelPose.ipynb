# %%
import cv2
import mediapipe as mp

# Initialize mediapipe holistic model and drawing utilities
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

# Start capturing video from the webcam
cap = cv2.VideoCapture(0)

# Check if the webcam is opened successfully
if not cap.isOpened():
    print("Error: Could not open webcam.")
    exit()

# Initiate holistic model
with mp_holistic.Holistic(min_detection_confidence=0.1, min_tracking_confidence=0.1) as holistic:
    while cap.isOpened():
        ret, frame = cap.read()

        # If frame is not read correctly, handle the error
        if not ret or frame is None:
            print("Error: Could not read frame.")
            break

        # Recolor Feed to RGB for Mediapipe processing
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        

        # Make Detections
        results = holistic.process(image)

        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Draw landmarks
        # (drawing logic remains the same)

        # Show the processed image
        cv2.imshow('Raw Webcam Feed', image)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the video capture object and close windows
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### Inference on video mediapipe

# %%
import cv2
import mediapipe as mp
import os

# Initialize mediapipe pose model and drawing utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Path to input video
video_path = r'C:\Users\Admin\Downloads\Body Language Detection with mediapipe\vid\9710109-uhd_3840_2160_25fps.mp4'

# Specify output folder and file
output_folder = 'output_videos'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
output_video_path = os.path.join(output_folder, r'C:\Users\Admin\Downloads\Body Language Detection with mediapipe\vid\MainProcessed.mp4')

# Start capturing video from the file
cap = cv2.VideoCapture(video_path)

# Get frame width, height, and FPS for saving the output video
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create VideoWriter object to save the video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Initiate pose model
with mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5, model_complexity=1) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Recolor Feed to RGB for Mediapipe processing
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False        
        
        # Make Detections
        results = pose.process(image)
        
        # Recolor image back to BGR for rendering
        image.flags.writeable = True   
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Draw Pose landmarks for the detected person
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS, 
                                      mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                      mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))
        
        # Write the processed frame to the output video
        out.write(image)
        
        # Show the processed image (optional)
        cv2.imshow('Processed Video Feed', image)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the video capture and writer objects, and close windows
cap.release()
out.release()
cv2.destroyAllWindows()

# %% [markdown]
# ### process multiple images in a video

# %%
import cv2
import mediapipe as mp
import torch
import os
from ultralytics import YOLO

# Initialize Mediapipe pose model and drawing utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Load YOLOv8 model for person detection
yolo_model = YOLO('yolov8n.pt')  # Use 'yolov8n.pt' for lightweight model

# Path to input video
video_path = r'C:\Users\Admin\Downloads\Body Language Detection with mediapipe\vid\9710109-uhd_3840_2160_25fps.mp4'

# Specify output folder and file
output_folder = 'output_videos'
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
output_video_path = os.path.join(output_folder, r'C:\Users\Admin\Downloads\Body Language Detection with mediapipe\vid\25fps.mp4')

# Start capturing video from the file
cap = cv2.VideoCapture(video_path)

# Get frame width, height, and FPS for saving the output video
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))

# Define the codec and create VideoWriter object to save the video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

# Initiate pose model
with mp_pose.Pose(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5, model_complexity=1) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # Use YOLO to detect people in the frame
        results = yolo_model(frame)
        detections = results[0]  # Get detections from YOLO
        
        # Process each person detected
        for det in detections.boxes:
            if det.cls == 0:  # Class 0 is for 'person' in YOLO
                # Get bounding box coordinates for each person
                x1, y1, x2, y2 = map(int, det.xyxy[0].cpu().numpy())

                # Extract the person from the frame using the bounding box
                person = frame[y1:y2, x1:x2]

                # Convert to RGB for Mediapipe processing
                person_rgb = cv2.cvtColor(person, cv2.COLOR_BGR2RGB)
                person_rgb.flags.writeable = False

                # Apply Mediapipe Pose estimation
                pose_results = pose.process(person_rgb)
                
                # Recolor the image back to BGR for display
                person_rgb.flags.writeable = True
                person_bgr = cv2.cvtColor(person_rgb, cv2.COLOR_RGB2BGR)

                # Draw Pose landmarks on the person
                if pose_results.pose_landmarks:
                    mp_drawing.draw_landmarks(person_bgr, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                              mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                              mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

                # Replace the processed person back into the original frame
                frame[y1:y2, x1:x2] = person_bgr
        
        # Write the processed frame to the output video
        out.write(frame)

        # Show the processed frame (optional)
        cv2.imshow('Processed Video Feed', frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

# Release the video capture and writer objects, and close windows
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 persons, 323.3ms
# Speed: 13.4ms preprocess, 323.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 160.0ms
# Speed: 3.5ms preprocess, 160.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 169.3ms
# Speed: 5.1ms preprocess, 169.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 222.4ms
# Speed: 6.3ms preprocess, 222.4ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 141.4ms
# Speed: 4.0ms preprocess, 141.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 118.2ms
# Speed: 3.3ms preprocess, 118.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 147.5ms
# Speed: 3.0ms preprocess, 147.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 152.0ms
# Speed: 4.0ms preprocess, 152.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 125.0ms
# Speed: 5.0ms preprocess, 125.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 142.0ms
# Speed: 3.3ms preprocess, 142.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 171.7ms
# Speed: 4.4ms preprocess, 171.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 169.2ms
# Speed: 7.1ms preprocess, 169.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 143.6ms
# Speed: 4.1ms preprocess, 143.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 175.1ms
# Speed: 5.1ms preprocess, 175.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 140.7ms
# Speed: 4.5ms preprocess, 140.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 116.3ms
# Speed: 4.0ms preprocess, 116.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 144.1ms
# Speed: 3.6ms preprocess, 144.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 201.0ms
# Speed: 7.1ms preprocess, 201.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 197.6ms
# Speed: 8.2ms preprocess, 197.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 154.6ms
# Speed: 6.0ms preprocess, 154.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 139.3ms
# Speed: 3.0ms preprocess, 139.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 113.4ms
# Speed: 3.1ms preprocess, 113.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 173.0ms
# Speed: 28.6ms preprocess, 173.0ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 139.9ms
# Speed: 4.5ms preprocess, 139.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 152.9ms
# Speed: 5.0ms preprocess, 152.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 258.6ms
# Speed: 3.7ms preprocess, 258.6ms inference, 3.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 216.8ms
# Speed: 7.4ms preprocess, 216.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 204.9ms
# Speed: 7.0ms preprocess, 204.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 250.9ms
# Speed: 8.0ms preprocess, 250.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 161.0ms
# Speed: 3.7ms preprocess, 161.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 173.3ms
# Speed: 5.3ms preprocess, 173.3ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 152.2ms
# Speed: 5.0ms preprocess, 152.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 160.9ms
# Speed: 3.9ms preprocess, 160.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 132.6ms
# Speed: 4.0ms preprocess, 132.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 163.2ms
# Speed: 5.0ms preprocess, 163.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 156.8ms
# Speed: 3.0ms preprocess, 156.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 115.8ms
# Speed: 3.1ms preprocess, 115.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 128.6ms
# Speed: 5.4ms preprocess, 128.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 114.1ms
# Speed: 3.1ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 121.6ms
# Speed: 4.1ms preprocess, 121.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 155.6ms
# Speed: 6.0ms preprocess, 155.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 133.0ms
# Speed: 5.2ms preprocess, 133.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 129.4ms
# Speed: 4.0ms preprocess, 129.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 99.7ms
# Speed: 3.8ms preprocess, 99.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 118.9ms
# Speed: 3.1ms preprocess, 118.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 123.9ms
# Speed: 5.0ms preprocess, 123.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 169.1ms
# Speed: 4.2ms preprocess, 169.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 115.1ms
# Speed: 6.3ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 121.9ms
# Speed: 5.0ms preprocess, 121.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 111.2ms
# Speed: 3.5ms preprocess, 111.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 116.8ms
# Speed: 3.2ms preprocess, 116.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 110.6ms
# Speed: 3.3ms preprocess, 110.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 213.8ms
# Speed: 8.1ms preprocess, 213.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 142.9ms
# Speed: 5.5ms preprocess, 142.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 115.7ms
# Speed: 4.4ms preprocess, 115.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 131.6ms
# Speed: 4.3ms preprocess, 131.6ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 213.7ms
# Speed: 2.5ms preprocess, 213.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 329.9ms
# Speed: 5.1ms preprocess, 329.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 182.2ms
# Speed: 3.0ms preprocess, 182.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 108.2ms
# Speed: 3.4ms preprocess, 108.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 167.6ms
# Speed: 3.5ms preprocess, 167.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 135.7ms
# Speed: 5.0ms preprocess, 135.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 193.8ms
# Speed: 5.4ms preprocess, 193.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 141.3ms
# Speed: 4.5ms preprocess, 141.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 150.1ms
# Speed: 4.5ms preprocess, 150.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 118.3ms
# Speed: 4.0ms preprocess, 118.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 230.3ms
# Speed: 5.7ms preprocess, 230.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 689.3ms
# Speed: 49.2ms preprocess, 689.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 198.8ms
# Speed: 4.3ms preprocess, 198.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 142.1ms
# Speed: 5.3ms preprocess, 142.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 201.4ms
# Speed: 4.4ms preprocess, 201.4ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 109.9ms
# Speed: 2.6ms preprocess, 109.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 243.0ms
# Speed: 43.2ms preprocess, 243.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 146.8ms
# Speed: 3.7ms preprocess, 146.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 116.7ms
# Speed: 3.0ms preprocess, 116.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 110.3ms
# Speed: 3.3ms preprocess, 110.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 143.6ms
# Speed: 4.3ms preprocess, 143.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 139.1ms
# Speed: 3.4ms preprocess, 139.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 107.5ms
# Speed: 4.1ms preprocess, 107.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 318.1ms
# Speed: 5.2ms preprocess, 318.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 183.4ms
# Speed: 4.0ms preprocess, 183.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 137.4ms
# Speed: 3.0ms preprocess, 137.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 113.0ms
# Speed: 3.2ms preprocess, 113.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 133.2ms
# Speed: 3.2ms preprocess, 133.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 116.6ms
# Speed: 3.0ms preprocess, 116.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 107.4ms
# Speed: 3.0ms preprocess, 107.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 225.2ms
# Speed: 5.5ms preprocess, 225.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 143.4ms
# Speed: 6.3ms preprocess, 143.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 106.8ms
# Speed: 3.3ms preprocess, 106.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 113.9ms
# Speed: 2.5ms preprocess, 113.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 125.2ms
# Speed: 4.5ms preprocess, 125.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 128.4ms
# Speed: 3.5ms preprocess, 128.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)

# %% [markdown]
# ### ON IMAGES IN A FOLDER

# %%
import cv2
import mediapipe as mp
import torch
import os
from ultralytics import YOLO

# Initialize Mediapipe pose model and drawing utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Load YOLOv8 model for person detection
yolo_model = YOLO('yolov8n.pt')  # Use 'yolov8n.pt' for lightweight model

# Specify input and output folder paths
input_folder = r'C:\Users\Admin\Downloads\data\im'
output_folder = r'C:\Users\Admin\Downloads\data\label'

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Initiate pose model
with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5, min_tracking_confidence=0.5, model_complexity=1) as pose:
    
    # Loop through each image in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith(('.jpg', '.jpeg', '.png')):  # Process only image files
            image_path = os.path.join(input_folder, file_name)

            # Read the image
            image = cv2.imread(image_path)

            # Use YOLO to detect people in the image
            results = yolo_model(image)
            detections = results[0]  # Get detections from YOLO
            
            # Process each person detected
            for det in detections.boxes:
                if det.cls == 0:  # Class 0 is for 'person' in YOLO
                    # Get bounding box coordinates for each person
                    x1, y1, x2, y2 = map(int, det.xyxy[0].cpu().numpy())

                    # Extract the person from the image using the bounding box
                    person = image[y1:y2, x1:x2]

                    # Convert to RGB for Mediapipe processing
                    person_rgb = cv2.cvtColor(person, cv2.COLOR_BGR2RGB)
                    person_rgb.flags.writeable = False

                    # Apply Mediapipe Pose estimation
                    pose_results = pose.process(person_rgb)
                    
                    # Recolor the image back to BGR for display
                    person_rgb.flags.writeable = True
                    person_bgr = cv2.cvtColor(person_rgb, cv2.COLOR_RGB2BGR)

                    # Draw Pose landmarks on the person
                    if pose_results.pose_landmarks:
                        mp_drawing.draw_landmarks(person_bgr, pose_results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2))

                    # Replace the processed person back into the original image
                    image[y1:y2, x1:x2] = person_bgr
            
            # Save the labeled image to the output folder
            output_image_path = os.path.join(output_folder, file_name)
            cv2.imwrite(output_image_path, image)

            print(f"Processed and saved: {output_image_path}")

# Release any resources if needed
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 persons, 160.0ms
# Speed: 19.0ms preprocess, 160.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_0.jpg
#
# 0: 384x640 4 persons, 106.2ms
# Speed: 2.4ms preprocess, 106.2ms inference, 6.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_1.jpg
#
# 0: 384x640 4 persons, 132.2ms
# Speed: 3.6ms preprocess, 132.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_2.jpg
#
# 0: 384x640 4 persons, 106.6ms
# Speed: 9.8ms preprocess, 106.6ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_3.jpg
#
# 0: 384x640 4 persons, 135.7ms
# Speed: 6.0ms preprocess, 135.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_4.jpg
#
# 0: 384x640 4 persons, 110.7ms
# Speed: 0.0ms preprocess, 110.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_5.jpg

# %% [markdown]
# ### labelling images in a folder saving labels in same folder as image

# %%
import cv2
import mediapipe as mp
import torch
import os
from ultralytics import YOLO

# Initialize Mediapipe pose model and drawing utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Load YOLOv8 model for person detection
yolo_model = YOLO('yolov8n.pt')  # Use 'yolov8n.pt' for lightweight model

# Specify input and output folder paths
input_folder = r'C:\Users\Admin\Downloads\data\im'
output_folder = r'C:\Users\Admin\Downloads\data\label'

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to normalize coordinates
def normalize(value, max_value):
    return value / max_value

# Initiate pose model
with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5, min_tracking_confidence=0.5, model_complexity=1) as pose:
    
    # Loop through each image in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith(('.jpg', '.jpeg', '.png')):  # Process only image files
            image_path = os.path.join(input_folder, file_name)

            # Read the image
            image = cv2.imread(image_path)
            height, width, _ = image.shape

            # Use YOLO to detect people in the image
            results = yolo_model(image)
            detections = results[0]  # Get detections from YOLO
            
            # Initialize label data for the image
            label_data = []

            # Process each person detected
            for det in detections.boxes:
                if det.cls == 0:  # Class 0 is for 'person' in YOLO
                    # Get bounding box coordinates for each person
                    x1, y1, x2, y2 = map(int, det.xyxy[0].cpu().numpy())

                    # Normalize bounding box coordinates
                    norm_x_center = normalize((x1 + x2) / 2, width)
                    norm_y_center = normalize((y1 + y2) / 2, height)
                    norm_width = normalize(x2 - x1, width)
                    norm_height = normalize(y2 - y1, height)

                    # Start label with the object class and bounding box data
                    person_label = [0, norm_x_center, norm_y_center, norm_width, norm_height]

                    # Extract the person from the image using the bounding box
                    person = image[y1:y2, x1:x2]

                    # Convert to RGB for Mediapipe processing
                    person_rgb = cv2.cvtColor(person, cv2.COLOR_BGR2RGB)
                    person_rgb.flags.writeable = False

                    # Apply Mediapipe Pose estimation
                    pose_results = pose.process(person_rgb)

                    # If pose landmarks detected, append them to the label
                    if pose_results.pose_landmarks:
                        for landmark in pose_results.pose_landmarks.landmark:
                            norm_x = normalize(landmark.x * (x2 - x1) + x1, width)
                            norm_y = normalize(landmark.y * (y2 - y1) + y1, height)
                            visibility = 2 if landmark.visibility > 0.5 else 0
                            person_label.extend([norm_x, norm_y, visibility])
                    else:
                        # If no landmarks are detected, fill with default values for missing landmarks
                        for _ in range(33):
                            person_label.extend([0, 0, 0])

                    # Append this person's label to the label_data
                    label_data.append(' '.join(map(str, person_label)))

            # Save the label data in a .txt file with the same name as the image
            if label_data:  # Only create label file if there's a person detected
                label_file_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}.txt")
                with open(label_file_path, 'w') as f:
                    f.write('\n'.join(label_data))

            # Save the labeled image to the output folder
            output_image_path = os.path.join(output_folder, file_name)
            cv2.imwrite(output_image_path, image)

            print(f"Processed and saved: {output_image_path}")

# Release any resources if needed
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 persons, 104.9ms
# Speed: 9.3ms preprocess, 104.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_0.jpg
#
# 0: 384x640 4 persons, 116.7ms
# Speed: 1.6ms preprocess, 116.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_1.jpg
#
# 0: 384x640 4 persons, 139.0ms
# Speed: 5.1ms preprocess, 139.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_2.jpg
#
# 0: 384x640 4 persons, 96.5ms
# Speed: 0.0ms preprocess, 96.5ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_3.jpg
#
# 0: 384x640 4 persons, 120.0ms
# Speed: 1.1ms preprocess, 120.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_4.jpg
#
# 0: 384x640 4 persons, 128.4ms
# Speed: 2.1ms preprocess, 128.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved: C:\Users\Admin\Downloads\data\label\img_5.jpg

# %% [markdown]
# ### labelling images in a folder saving labels in different folder as image

# %%
import cv2
import mediapipe as mp
import torch
import os
from ultralytics import YOLO

# Initialize Mediapipe pose model and drawing utilities
mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# Load YOLOv8 model for person detection
yolo_model = YOLO('yolov8n.pt')  # Use 'yolov8n.pt' for lightweight model

# Specify input and output folder paths
input_folder = r'C:\Users\Admin\Downloads\data\images'
output_folder = r'C:\Users\Admin\Downloads\data\label'

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to normalize coordinates
def normalize(value, max_value):
    return value / max_value

# Initiate pose model
with mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5, min_tracking_confidence=0.5, model_complexity=1) as pose:
    
    # Loop through each image in the input folder
    for file_name in os.listdir(input_folder):
        if file_name.endswith(('.jpg', '.jpeg', '.png')):  # Process only image files
            image_path = os.path.join(input_folder, file_name)

            # Read the image
            image = cv2.imread(image_path)
            height, width, _ = image.shape

            # Use YOLO to detect people in the image
            results = yolo_model(image)
            detections = results[0]  # Get detections from YOLO
            
            # Initialize label data for the image
            label_data = []

            # Process each person detected
            for det in detections.boxes:
                if det.cls == 0:  # Class 0 is for 'person' in YOLO
                    # Get bounding box coordinates for each person
                    x1, y1, x2, y2 = map(int, det.xyxy[0].cpu().numpy())

                    # Normalize bounding box coordinates
                    norm_x_center = normalize((x1 + x2) / 2, width)
                    norm_y_center = normalize((y1 + y2) / 2, height)
                    norm_width = normalize(x2 - x1, width)
                    norm_height = normalize(y2 - y1, height)

                    # Start label with the object class and bounding box data
                    person_label = [0, norm_x_center, norm_y_center, norm_width, norm_height]

                    # Extract the person from the image using the bounding box
                    person = image[y1:y2, x1:x2]

                    # Convert to RGB for Mediapipe processing
                    person_rgb = cv2.cvtColor(person, cv2.COLOR_BGR2RGB)
                    person_rgb.flags.writeable = False

                    # Apply Mediapipe Pose estimation
                    pose_results = pose.process(person_rgb)

                    # If pose landmarks detected, append them to the label
                    if pose_results.pose_landmarks:
                        for landmark in pose_results.pose_landmarks.landmark:
                            norm_x = normalize(landmark.x * (x2 - x1) + x1, width)
                            norm_y = normalize(landmark.y * (y2 - y1) + y1, height)
                            visibility = 2 if landmark.visibility > 0.5 else 0
                            person_label.extend([norm_x, norm_y, visibility])
                    else:
                        # If no landmarks are detected, fill with default values for missing landmarks
                        for _ in range(33):
                            person_label.extend([0, 0, 0])

                    # Append this person's label to the label_data
                    label_data.append(' '.join(map(str, person_label)))

            # Save the label data in a .txt file with the same name as the image
            if label_data:  # Only create label file if there's a person detected
                label_file_path = os.path.join(output_folder, f"{os.path.splitext(file_name)[0]}.txt")
                with open(label_file_path, 'w') as f:
                    f.write('\n'.join(label_data))

            print(f"Processed and saved labels for: {file_name}")

# Release any resources if needed
cv2.destroyAllWindows()
# Out:
# 0: 384x640 4 persons, 130.9ms
# Speed: 9.1ms preprocess, 130.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_0.jpg
#
# 0: 384x640 4 persons, 106.0ms
# Speed: 2.5ms preprocess, 106.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_1.jpg
#
# 0: 384x640 4 persons, 83.8ms
# Speed: 1.1ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_10.jpg
#
# 0: 384x640 4 persons, 101.7ms
# Speed: 1.6ms preprocess, 101.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_100.jpg
#
# 0: 384x640 4 persons, 143.8ms
# Speed: 4.5ms preprocess, 143.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_101.jpg
#
# 0: 384x640 4 persons, 120.9ms
# Speed: 6.1ms preprocess, 120.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_102.jpg
#
# 0: 384x640 4 persons, 140.7ms
# Speed: 0.0ms preprocess, 140.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_103.jpg
#
# 0: 384x640 4 persons, 127.8ms
# Speed: 2.2ms preprocess, 127.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_104.jpg
#
# 0: 384x640 4 persons, 130.7ms
# Speed: 3.6ms preprocess, 130.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_105.jpg
#
# 0: 384x640 4 persons, 123.9ms
# Speed: 5.0ms preprocess, 123.9ms inference, 7.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_106.jpg
#
# 0: 384x640 4 persons, 126.7ms
# Speed: 3.3ms preprocess, 126.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_107.jpg
#
# 0: 384x640 4 persons, 181.1ms
# Speed: 1.0ms preprocess, 181.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_108.jpg
#
# 0: 384x640 4 persons, 171.3ms
# Speed: 9.1ms preprocess, 171.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_109.jpg
#
# 0: 384x640 4 persons, 117.4ms
# Speed: 0.0ms preprocess, 117.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_11.jpg
#
# 0: 384x640 4 persons, 130.0ms
# Speed: 0.0ms preprocess, 130.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_110.jpg
#
# 0: 384x640 4 persons, 115.2ms
# Speed: 3.6ms preprocess, 115.2ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_111.jpg
#
# 0: 384x640 4 persons, 179.8ms
# Speed: 0.0ms preprocess, 179.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_112.jpg
#
# 0: 384x640 4 persons, 151.1ms
# Speed: 4.5ms preprocess, 151.1ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_113.jpg
#
# 0: 384x640 4 persons, 111.2ms
# Speed: 0.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_114.jpg
#
# 0: 384x640 4 persons, 138.9ms
# Speed: 9.1ms preprocess, 138.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_115.jpg
#
# 0: 384x640 4 persons, 127.5ms
# Speed: 0.0ms preprocess, 127.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_116.jpg
#
# 0: 384x640 4 persons, 109.1ms
# Speed: 8.6ms preprocess, 109.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_117.jpg
#
# 0: 384x640 4 persons, 164.3ms
# Speed: 7.0ms preprocess, 164.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_118.jpg
#
# 0: 384x640 4 persons, 148.4ms
# Speed: 0.0ms preprocess, 148.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_119.jpg
#
# 0: 384x640 4 persons, 120.0ms
# Speed: 5.7ms preprocess, 120.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_12.jpg
#
# 0: 384x640 4 persons, 230.3ms
# Speed: 8.5ms preprocess, 230.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_120.jpg
#
# 0: 384x640 4 persons, 161.9ms
# Speed: 8.0ms preprocess, 161.9ms inference, 8.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_121.jpg
#
# 0: 384x640 4 persons, 100.0ms
# Speed: 0.0ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_122.jpg
#
# 0: 384x640 4 persons, 123.3ms
# Speed: 5.5ms preprocess, 123.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_123.jpg
#
# 0: 384x640 4 persons, 114.6ms
# Speed: 8.1ms preprocess, 114.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_124.jpg
#
# 0: 384x640 4 persons, 140.1ms
# Speed: 0.0ms preprocess, 140.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_125.jpg
#
# 0: 384x640 4 persons, 108.7ms
# Speed: 0.0ms preprocess, 108.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_126.jpg
#
# 0: 384x640 4 persons, 101.1ms
# Speed: 7.5ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_127.jpg
#
# 0: 384x640 4 persons, 139.9ms
# Speed: 0.0ms preprocess, 139.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_128.jpg
#
# 0: 384x640 4 persons, 98.7ms
# Speed: 4.3ms preprocess, 98.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_129.jpg
#
# 0: 384x640 4 persons, 99.3ms
# Speed: 0.0ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_13.jpg
#
# 0: 384x640 4 persons, 95.7ms
# Speed: 0.0ms preprocess, 95.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_130.jpg
#
# 0: 384x640 4 persons, 111.4ms
# Speed: 0.0ms preprocess, 111.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_131.jpg
#
# 0: 384x640 4 persons, 104.2ms
# Speed: 1.2ms preprocess, 104.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_132.jpg
#
# 0: 384x640 4 persons, 128.8ms
# Speed: 0.0ms preprocess, 128.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_133.jpg
#
# 0: 384x640 4 persons, 243.0ms
# Speed: 1.7ms preprocess, 243.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_134.jpg
#
# 0: 384x640 4 persons, 97.4ms
# Speed: 0.0ms preprocess, 97.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_135.jpg
#
# 0: 384x640 4 persons, 89.5ms
# Speed: 0.0ms preprocess, 89.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_136.jpg
#
# 0: 384x640 4 persons, 99.9ms
# Speed: 1.0ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_137.jpg
#
# 0: 384x640 4 persons, 99.9ms
# Speed: 9.0ms preprocess, 99.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_138.jpg
#
# 0: 384x640 4 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_139.jpg
#
# 0: 384x640 4 persons, 131.5ms
# Speed: 0.0ms preprocess, 131.5ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_14.jpg
#
# 0: 384x640 4 persons, 168.5ms
# Speed: 2.1ms preprocess, 168.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_140.jpg
#
# 0: 384x640 4 persons, 154.3ms
# Speed: 0.0ms preprocess, 154.3ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_141.jpg
#
# 0: 384x640 4 persons, 348.1ms
# Speed: 10.0ms preprocess, 348.1ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_142.jpg
#
# 0: 384x640 4 persons, 146.4ms
# Speed: 4.1ms preprocess, 146.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_143.jpg
#
# 0: 384x640 4 persons, 143.3ms
# Speed: 4.0ms preprocess, 143.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_144.jpg
#
# 0: 384x640 4 persons, 130.8ms
# Speed: 5.0ms preprocess, 130.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_145.jpg
#
# 0: 384x640 4 persons, 251.8ms
# Speed: 0.0ms preprocess, 251.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_146.jpg
#
# 0: 384x640 4 persons, 197.5ms
# Speed: 44.5ms preprocess, 197.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_147.jpg
#
# 0: 384x640 4 persons, 160.3ms
# Speed: 0.0ms preprocess, 160.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_148.jpg
#
# 0: 384x640 4 persons, 169.9ms
# Speed: 10.1ms preprocess, 169.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_149.jpg
#
# 0: 384x640 4 persons, 247.7ms
# Speed: 0.0ms preprocess, 247.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_15.jpg
#
# 0: 384x640 4 persons, 133.2ms
# Speed: 9.6ms preprocess, 133.2ms inference, 6.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_150.jpg
#
# 0: 384x640 4 persons, 120.1ms
# Speed: 4.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_151.jpg
#
# 0: 384x640 4 persons, 111.4ms
# Speed: 0.0ms preprocess, 111.4ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_152.jpg
#
# 0: 384x640 4 persons, 110.1ms
# Speed: 0.0ms preprocess, 110.1ms inference, 9.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_153.jpg
#
# 0: 384x640 4 persons, 129.1ms
# Speed: 7.0ms preprocess, 129.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_154.jpg
#
# 0: 384x640 4 persons, 115.2ms
# Speed: 0.0ms preprocess, 115.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_155.jpg
#
# 0: 384x640 4 persons, 119.5ms
# Speed: 3.3ms preprocess, 119.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_156.jpg
#
# 0: 384x640 4 persons, 411.3ms
# Speed: 5.0ms preprocess, 411.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_157.jpg
#
# 0: 384x640 4 persons, 140.7ms
# Speed: 0.0ms preprocess, 140.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_158.jpg
#
# 0: 384x640 4 persons, 361.4ms
# Speed: 9.9ms preprocess, 361.4ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_159.jpg
#
# 0: 384x640 4 persons, 910.0ms
# Speed: 8.3ms preprocess, 910.0ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_16.jpg
#
# 0: 384x640 4 persons, 150.1ms
# Speed: 7.2ms preprocess, 150.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_160.jpg
#
# 0: 384x640 4 persons, 174.7ms
# Speed: 11.0ms preprocess, 174.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_161.jpg
#
# 0: 384x640 4 persons, 244.1ms
# Speed: 4.0ms preprocess, 244.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_162.jpg
#
# 0: 384x640 4 persons, 147.8ms
# Speed: 0.0ms preprocess, 147.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_163.jpg
#
# 0: 384x640 4 persons, 121.3ms
# Speed: 3.6ms preprocess, 121.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_164.jpg
#
# 0: 384x640 4 persons, 193.7ms
# Speed: 8.6ms preprocess, 193.7ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_165.jpg
#
# 0: 384x640 4 persons, 133.0ms
# Speed: 2.2ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_166.jpg
#
# 0: 384x640 4 persons, 111.5ms
# Speed: 0.0ms preprocess, 111.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_167.jpg
#
# 0: 384x640 4 persons, 108.6ms
# Speed: 0.0ms preprocess, 108.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_168.jpg
#
# 0: 384x640 4 persons, 114.0ms
# Speed: 6.5ms preprocess, 114.0ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_169.jpg
#
# 0: 384x640 4 persons, 111.5ms
# Speed: 8.6ms preprocess, 111.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_17.jpg
#
# 0: 384x640 4 persons, 138.0ms
# Speed: 2.1ms preprocess, 138.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_170.jpg
#
# 0: 384x640 4 persons, 176.0ms
# Speed: 8.0ms preprocess, 176.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_171.jpg
#
# 0: 384x640 4 persons, 162.3ms
# Speed: 5.0ms preprocess, 162.3ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_172.jpg
#
# 0: 384x640 4 persons, 158.5ms
# Speed: 0.0ms preprocess, 158.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_173.jpg
#
# 0: 384x640 4 persons, 104.6ms
# Speed: 0.0ms preprocess, 104.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_174.jpg
#
# 0: 384x640 4 persons, 154.6ms
# Speed: 7.1ms preprocess, 154.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_175.jpg
#
# 0: 384x640 4 persons, 129.2ms
# Speed: 9.6ms preprocess, 129.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_176.jpg
#
# 0: 384x640 4 persons, 102.7ms
# Speed: 0.0ms preprocess, 102.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_177.jpg
#
# 0: 384x640 4 persons, 146.7ms
# Speed: 2.1ms preprocess, 146.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_178.jpg
#
# 0: 384x640 4 persons, 162.0ms
# Speed: 0.0ms preprocess, 162.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_179.jpg
#
# 0: 384x640 4 persons, 120.0ms
# Speed: 0.0ms preprocess, 120.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_18.jpg
#
# 0: 384x640 4 persons, 94.0ms
# Speed: 3.4ms preprocess, 94.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_180.jpg
#
# 0: 384x640 4 persons, 100.2ms
# Speed: 1.1ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_181.jpg
#
# 0: 384x640 4 persons, 111.7ms
# Speed: 0.5ms preprocess, 111.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_182.jpg
#
# 0: 384x640 4 persons, 119.9ms
# Speed: 8.6ms preprocess, 119.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_183.jpg
#
# 0: 384x640 4 persons, 109.3ms
# Speed: 8.6ms preprocess, 109.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_184.jpg
#
# 0: 384x640 4 persons, 102.3ms
# Speed: 4.5ms preprocess, 102.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_185.jpg
#
# 0: 384x640 4 persons, 101.1ms
# Speed: 10.2ms preprocess, 101.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_186.jpg
#
# 0: 384x640 4 persons, 156.9ms
# Speed: 0.0ms preprocess, 156.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_187.jpg
#
# 0: 384x640 4 persons, 120.5ms
# Speed: 8.0ms preprocess, 120.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_188.jpg
#
# 0: 384x640 4 persons, 111.2ms
# Speed: 9.0ms preprocess, 111.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_189.jpg
#
# 0: 384x640 4 persons, 119.7ms
# Speed: 0.0ms preprocess, 119.7ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_19.jpg
#
# 0: 384x640 4 persons, 127.2ms
# Speed: 4.0ms preprocess, 127.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_190.jpg
#
# 0: 384x640 4 persons, 94.2ms
# Speed: 5.5ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_191.jpg
#
# 0: 384x640 4 persons, 115.6ms
# Speed: 3.0ms preprocess, 115.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_192.jpg
#
# 0: 384x640 4 persons, 123.0ms
# Speed: 4.0ms preprocess, 123.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_193.jpg
#
# 0: 384x640 4 persons, 108.9ms
# Speed: 5.0ms preprocess, 108.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_194.jpg
#
# 0: 384x640 4 persons, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_195.jpg
#
# 0: 384x640 4 persons, 101.0ms
# Speed: 0.0ms preprocess, 101.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_196.jpg
#
# 0: 384x640 4 persons, 96.0ms
# Speed: 3.7ms preprocess, 96.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_197.jpg
#
# 0: 384x640 4 persons, 114.7ms
# Speed: 5.1ms preprocess, 114.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_198.jpg
#
# 0: 384x640 4 persons, 94.4ms
# Speed: 4.7ms preprocess, 94.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_199.jpg
#
# 0: 384x640 4 persons, 151.3ms
# Speed: 0.0ms preprocess, 151.3ms inference, 9.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_2.jpg
#
# 0: 384x640 4 persons, 100.5ms
# Speed: 5.0ms preprocess, 100.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_20.jpg
#
# 0: 384x640 4 persons, 129.0ms
# Speed: 0.0ms preprocess, 129.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_200.jpg
#
# 0: 384x640 4 persons, 96.7ms
# Speed: 3.3ms preprocess, 96.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_201.jpg
#
# 0: 384x640 4 persons, 139.9ms
# Speed: 1.1ms preprocess, 139.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_202.jpg
#
# 0: 384x640 4 persons, 134.9ms
# Speed: 9.5ms preprocess, 134.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_203.jpg
#
# 0: 384x640 4 persons, 107.4ms
# Speed: 0.0ms preprocess, 107.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_204.jpg
#
# 0: 384x640 4 persons, 142.8ms
# Speed: 10.7ms preprocess, 142.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_205.jpg
#
# 0: 384x640 4 persons, 111.9ms
# Speed: 5.6ms preprocess, 111.9ms inference, 7.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_206.jpg
#
# 0: 384x640 4 persons, 106.7ms
# Speed: 1.8ms preprocess, 106.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_207.jpg
#
# 0: 384x640 4 persons, 112.6ms
# Speed: 3.0ms preprocess, 112.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_208.jpg
#
# 0: 384x640 4 persons, 114.5ms
# Speed: 9.1ms preprocess, 114.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_209.jpg
#
# 0: 384x640 4 persons, 101.4ms
# Speed: 0.0ms preprocess, 101.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_21.jpg
#
# 0: 384x640 4 persons, 114.4ms
# Speed: 3.0ms preprocess, 114.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_210.jpg
#
# 0: 384x640 4 persons, 104.3ms
# Speed: 1.0ms preprocess, 104.3ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_211.jpg
#
# 0: 384x640 4 persons, 105.2ms
# Speed: 8.6ms preprocess, 105.2ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_212.jpg
#
# 0: 384x640 4 persons, 133.6ms
# Speed: 2.8ms preprocess, 133.6ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_213.jpg
#
# 0: 384x640 4 persons, 129.8ms
# Speed: 6.0ms preprocess, 129.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_214.jpg
#
# 0: 384x640 4 persons, 113.7ms
# Speed: 4.8ms preprocess, 113.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_215.jpg
#
# 0: 384x640 4 persons, 106.4ms
# Speed: 0.0ms preprocess, 106.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_216.jpg
#
# 0: 384x640 4 persons, 117.7ms
# Speed: 0.0ms preprocess, 117.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_217.jpg
#
# 0: 384x640 4 persons, 116.9ms
# Speed: 1.9ms preprocess, 116.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_218.jpg
#
# 0: 384x640 4 persons, 189.7ms
# Speed: 7.0ms preprocess, 189.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_219.jpg
#
# 0: 384x640 4 persons, 137.5ms
# Speed: 0.0ms preprocess, 137.5ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_22.jpg
#
# 0: 384x640 4 persons, 161.2ms
# Speed: 5.4ms preprocess, 161.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_220.jpg
#
# 0: 384x640 4 persons, 160.1ms
# Speed: 7.6ms preprocess, 160.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_221.jpg
#
# 0: 384x640 4 persons, 132.7ms
# Speed: 1.3ms preprocess, 132.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_222.jpg
#
# 0: 384x640 4 persons, 102.6ms
# Speed: 0.0ms preprocess, 102.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_223.jpg
#
# 0: 384x640 4 persons, 123.1ms
# Speed: 2.4ms preprocess, 123.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_224.jpg
#
# 0: 384x640 4 persons, 104.2ms
# Speed: 0.0ms preprocess, 104.2ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_225.jpg
#
# 0: 384x640 4 persons, 120.4ms
# Speed: 7.6ms preprocess, 120.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_226.jpg
#
# 0: 384x640 4 persons, 162.2ms
# Speed: 0.0ms preprocess, 162.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_227.jpg
#
# 0: 384x640 4 persons, 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_228.jpg
#
# 0: 384x640 4 persons, 91.8ms
# Speed: 7.4ms preprocess, 91.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_229.jpg
#
# 0: 384x640 4 persons, 93.1ms
# Speed: 0.0ms preprocess, 93.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_23.jpg
#
# 0: 384x640 4 persons, 104.5ms
# Speed: 2.7ms preprocess, 104.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_230.jpg
#
# 0: 384x640 4 persons, 108.6ms
# Speed: 0.0ms preprocess, 108.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_231.jpg
#
# 0: 384x640 4 persons, 221.2ms
# Speed: 5.6ms preprocess, 221.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_232.jpg
#
# 0: 384x640 4 persons, 164.3ms
# Speed: 0.0ms preprocess, 164.3ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_233.jpg
#
# 0: 384x640 4 persons, 323.4ms
# Speed: 6.7ms preprocess, 323.4ms inference, 6.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_234.jpg
#
# 0: 384x640 4 persons, 166.5ms
# Speed: 8.8ms preprocess, 166.5ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_235.jpg
#
# 0: 384x640 4 persons, 206.0ms
# Speed: 6.5ms preprocess, 206.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_236.jpg
#
# 0: 384x640 4 persons, 93.0ms
# Speed: 1.2ms preprocess, 93.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_237.jpg
#
# 0: 384x640 4 persons, 121.7ms
# Speed: 2.5ms preprocess, 121.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_238.jpg
#
# 0: 384x640 4 persons, 150.8ms
# Speed: 3.1ms preprocess, 150.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_239.jpg
#
# 0: 384x640 4 persons, 153.5ms
# Speed: 6.7ms preprocess, 153.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_24.jpg
#
# 0: 384x640 4 persons, 209.7ms
# Speed: 3.0ms preprocess, 209.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_240.jpg
#
# 0: 384x640 4 persons, 145.9ms
# Speed: 4.0ms preprocess, 145.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_241.jpg
#
# 0: 384x640 4 persons, 131.3ms
# Speed: 3.5ms preprocess, 131.3ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_242.jpg
#
# 0: 384x640 4 persons, 249.8ms
# Speed: 4.0ms preprocess, 249.8ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_243.jpg
#
# 0: 384x640 4 persons, 154.5ms
# Speed: 3.5ms preprocess, 154.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_244.jpg
#
# 0: 384x640 4 persons, 309.0ms
# Speed: 4.1ms preprocess, 309.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_245.jpg
#
# 0: 384x640 4 persons, 181.3ms
# Speed: 6.7ms preprocess, 181.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_246.jpg
#
# 0: 384x640 4 persons, 165.6ms
# Speed: 5.1ms preprocess, 165.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_247.jpg
#
# 0: 384x640 4 persons, 96.1ms
# Speed: 2.5ms preprocess, 96.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_248.jpg
#
# 0: 384x640 4 persons, 106.2ms
# Speed: 4.0ms preprocess, 106.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_249.jpg
#
# 0: 384x640 4 persons, 118.1ms
# Speed: 3.5ms preprocess, 118.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_25.jpg
#
# 0: 384x640 4 persons, 139.3ms
# Speed: 2.9ms preprocess, 139.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_250.jpg
#
# 0: 384x640 4 persons, 148.9ms
# Speed: 4.4ms preprocess, 148.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_251.jpg
#
# 0: 384x640 4 persons, 174.9ms
# Speed: 2.0ms preprocess, 174.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_252.jpg
#
# 0: 384x640 4 persons, 179.8ms
# Speed: 6.9ms preprocess, 179.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_253.jpg
#
# 0: 384x640 4 persons, 270.2ms
# Speed: 118.7ms preprocess, 270.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_254.jpg
#
# 0: 384x640 4 persons, 311.5ms
# Speed: 2.5ms preprocess, 311.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_255.jpg
#
# 0: 384x640 4 persons, 151.2ms
# Speed: 0.0ms preprocess, 151.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_256.jpg
#
# 0: 384x640 4 persons, 119.1ms
# Speed: 0.0ms preprocess, 119.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_257.jpg
#
# 0: 384x640 4 persons, 115.2ms
# Speed: 5.0ms preprocess, 115.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_258.jpg
#
# 0: 384x640 4 persons, 92.7ms
# Speed: 9.2ms preprocess, 92.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_259.jpg
#
# 0: 384x640 4 persons, 104.5ms
# Speed: 3.1ms preprocess, 104.5ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_26.jpg
#
# 0: 384x640 4 persons, 111.0ms
# Speed: 8.6ms preprocess, 111.0ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_260.jpg
#
# 0: 384x640 4 persons, 98.7ms
# Speed: 2.2ms preprocess, 98.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_261.jpg
#
# 0: 384x640 4 persons, 228.8ms
# Speed: 4.5ms preprocess, 228.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_262.jpg
#
# 0: 384x640 4 persons, 98.7ms
# Speed: 5.4ms preprocess, 98.7ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_263.jpg
#
# 0: 384x640 4 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_264.jpg
#
# 0: 384x640 4 persons, 121.7ms
# Speed: 0.0ms preprocess, 121.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_265.jpg
#
# 0: 384x640 4 persons, 112.9ms
# Speed: 0.0ms preprocess, 112.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_266.jpg
#
# 0: 384x640 4 persons, 287.2ms
# Speed: 0.0ms preprocess, 287.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_267.jpg
#
# 0: 384x640 4 persons, 114.4ms
# Speed: 0.5ms preprocess, 114.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_268.jpg
#
# 0: 384x640 4 persons, 124.5ms
# Speed: 8.1ms preprocess, 124.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_269.jpg
#
# 0: 384x640 4 persons, 98.0ms
# Speed: 3.0ms preprocess, 98.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_27.jpg
#
# 0: 384x640 4 persons, 98.1ms
# Speed: 0.0ms preprocess, 98.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_270.jpg
#
# 0: 384x640 4 persons, 121.7ms
# Speed: 0.0ms preprocess, 121.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_271.jpg
#
# 0: 384x640 4 persons, 107.8ms
# Speed: 3.6ms preprocess, 107.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_272.jpg
#
# 0: 384x640 4 persons, 91.4ms
# Speed: 4.2ms preprocess, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_273.jpg
#
# 0: 384x640 4 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_274.jpg
#
# 0: 384x640 4 persons, 92.8ms
# Speed: 0.0ms preprocess, 92.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_275.jpg
#
# 0: 384x640 4 persons, 169.1ms
# Speed: 5.5ms preprocess, 169.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_276.jpg
#
# 0: 384x640 4 persons, 138.8ms
# Speed: 0.0ms preprocess, 138.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_277.jpg
#
# 0: 384x640 4 persons, 125.1ms
# Speed: 6.0ms preprocess, 125.1ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_278.jpg
#
# 0: 384x640 4 persons, 106.5ms
# Speed: 3.4ms preprocess, 106.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_279.jpg
#
# 0: 384x640 4 persons, 99.2ms
# Speed: 5.6ms preprocess, 99.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_28.jpg
#
# 0: 384x640 4 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_280.jpg
#
# 0: 384x640 4 persons, 192.8ms
# Speed: 2.7ms preprocess, 192.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_281.jpg
#
# 0: 384x640 4 persons, 102.7ms
# Speed: 0.0ms preprocess, 102.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_282.jpg
#
# 0: 384x640 4 persons, 108.0ms
# Speed: 1.8ms preprocess, 108.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_283.jpg
#
# 0: 384x640 4 persons, 116.0ms
# Speed: 0.0ms preprocess, 116.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_284.jpg
#
# 0: 384x640 4 persons, 185.2ms
# Speed: 2.0ms preprocess, 185.2ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_285.jpg
#
# 0: 384x640 4 persons, 169.9ms
# Speed: 3.7ms preprocess, 169.9ms inference, 9.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_286.jpg
#
# 0: 384x640 4 persons, 151.2ms
# Speed: 6.0ms preprocess, 151.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_287.jpg
#
# 0: 384x640 4 persons, 108.3ms
# Speed: 8.6ms preprocess, 108.3ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_288.jpg
#
# 0: 384x640 4 persons, 108.6ms
# Speed: 0.0ms preprocess, 108.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_289.jpg
#
# 0: 384x640 4 persons, 154.6ms
# Speed: 0.0ms preprocess, 154.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_29.jpg
#
# 0: 384x640 4 persons, 129.0ms
# Speed: 0.0ms preprocess, 129.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_290.jpg
#
# 0: 384x640 4 persons, 107.9ms
# Speed: 0.0ms preprocess, 107.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_291.jpg
#
# 0: 384x640 4 persons, 172.8ms
# Speed: 2.2ms preprocess, 172.8ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_292.jpg
#
# 0: 384x640 4 persons, 205.4ms
# Speed: 3.8ms preprocess, 205.4ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_293.jpg
#
# 0: 384x640 4 persons, 196.7ms
# Speed: 5.6ms preprocess, 196.7ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_294.jpg
#
# 0: 384x640 4 persons, 258.8ms
# Speed: 0.0ms preprocess, 258.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_295.jpg
#
# 0: 384x640 4 persons, 116.9ms
# Speed: 0.0ms preprocess, 116.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_296.jpg
#
# 0: 384x640 4 persons, 748.8ms
# Speed: 20.1ms preprocess, 748.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_297.jpg
#
# 0: 384x640 4 persons, 290.2ms
# Speed: 4.0ms preprocess, 290.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_298.jpg
#
# 0: 384x640 4 persons, 219.8ms
# Speed: 9.0ms preprocess, 219.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_299.jpg
#
# 0: 384x640 4 persons, 134.6ms
# Speed: 3.6ms preprocess, 134.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_3.jpg
#
# 0: 384x640 4 persons, 121.8ms
# Speed: 3.6ms preprocess, 121.8ms inference, 10.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_30.jpg
#
# 0: 384x640 4 persons, 260.5ms
# Speed: 3.0ms preprocess, 260.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_300.jpg
#
# 0: 384x640 4 persons, 125.6ms
# Speed: 4.0ms preprocess, 125.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_301.jpg
#
# 0: 384x640 4 persons, 131.1ms
# Speed: 0.0ms preprocess, 131.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_302.jpg
#
# 0: 384x640 4 persons, 130.5ms
# Speed: 9.5ms preprocess, 130.5ms inference, 4.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_303.jpg
#
# 0: 384x640 4 persons, 106.7ms
# Speed: 4.5ms preprocess, 106.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_304.jpg
#
# 0: 384x640 4 persons, 133.4ms
# Speed: 1.2ms preprocess, 133.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_305.jpg
#
# 0: 384x640 4 persons, 129.3ms
# Speed: 0.0ms preprocess, 129.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_306.jpg
#
# 0: 384x640 4 persons, 151.1ms
# Speed: 4.1ms preprocess, 151.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_307.jpg
#
# 0: 384x640 4 persons, 112.9ms
# Speed: 0.1ms preprocess, 112.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_308.jpg
#
# 0: 384x640 4 persons, 102.1ms
# Speed: 3.0ms preprocess, 102.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_309.jpg
#
# 0: 384x640 4 persons, 144.1ms
# Speed: 6.0ms preprocess, 144.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_31.jpg
#
# 0: 384x640 4 persons, 127.6ms
# Speed: 7.3ms preprocess, 127.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_310.jpg
#
# 0: 384x640 4 persons, 103.1ms
# Speed: 2.6ms preprocess, 103.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_311.jpg
#
# 0: 384x640 4 persons, 111.0ms
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_312.jpg
#
# 0: 384x640 4 persons, 100.0ms
# Speed: 2.3ms preprocess, 100.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_313.jpg
#
# 0: 384x640 4 persons, 214.2ms
# Speed: 6.0ms preprocess, 214.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_314.jpg
#
# 0: 384x640 4 persons, 134.8ms
# Speed: 7.6ms preprocess, 134.8ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_315.jpg
#
# 0: 384x640 4 persons, 110.8ms
# Speed: 5.1ms preprocess, 110.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_316.jpg
#
# 0: 384x640 4 persons, 95.0ms
# Speed: 3.0ms preprocess, 95.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_317.jpg
#
# 0: 384x640 4 persons, 127.9ms
# Speed: 0.0ms preprocess, 127.9ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_318.jpg
#
# 0: 384x640 4 persons, 101.2ms
# Speed: 8.6ms preprocess, 101.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_319.jpg
#
# 0: 384x640 4 persons, 491.1ms
# Speed: 0.0ms preprocess, 491.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_32.jpg
#
# 0: 384x640 4 persons, 295.2ms
# Speed: 7.5ms preprocess, 295.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_320.jpg
#
# 0: 384x640 4 persons, 120.6ms
# Speed: 0.0ms preprocess, 120.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_321.jpg
#
# 0: 384x640 4 persons, 151.6ms
# Speed: 3.7ms preprocess, 151.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_322.jpg
#
# 0: 384x640 4 persons, 99.8ms
# Speed: 0.0ms preprocess, 99.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_323.jpg
#
# 0: 384x640 4 persons, 102.4ms
# Speed: 2.8ms preprocess, 102.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_324.jpg
#
# 0: 384x640 4 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_325.jpg
#
# 0: 384x640 4 persons, 99.9ms
# Speed: 7.1ms preprocess, 99.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_326.jpg
#
# 0: 384x640 4 persons, 111.0ms
# Speed: 0.0ms preprocess, 111.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_327.jpg
#
# 0: 384x640 4 persons, 104.3ms
# Speed: 0.0ms preprocess, 104.3ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_328.jpg
#
# 0: 384x640 4 persons, 143.7ms
# Speed: 3.0ms preprocess, 143.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_329.jpg
#
# 0: 384x640 4 persons, 153.0ms
# Speed: 9.1ms preprocess, 153.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_33.jpg
#
# 0: 384x640 4 persons, 129.6ms
# Speed: 6.6ms preprocess, 129.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_330.jpg
#
# 0: 384x640 4 persons, 115.1ms
# Speed: 2.0ms preprocess, 115.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_331.jpg
#
# 0: 384x640 4 persons, 98.4ms
# Speed: 3.2ms preprocess, 98.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_332.jpg
#
# 0: 384x640 4 persons, 91.2ms
# Speed: 10.7ms preprocess, 91.2ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_333.jpg
#
# 0: 384x640 4 persons, 109.5ms
# Speed: 5.1ms preprocess, 109.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_334.jpg
#
# 0: 384x640 4 persons, 186.8ms
# Speed: 3.3ms preprocess, 186.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_335.jpg
#
# 0: 384x640 4 persons, 113.9ms
# Speed: 2.8ms preprocess, 113.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_336.jpg
#
# 0: 384x640 4 persons, 106.4ms
# Speed: 3.9ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_337.jpg
#
# 0: 384x640 4 persons, 100.2ms
# Speed: 6.6ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_338.jpg
#
# 0: 384x640 4 persons, 97.5ms
# Speed: 5.6ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_339.jpg
#
# 0: 384x640 4 persons, 167.7ms
# Speed: 2.2ms preprocess, 167.7ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_34.jpg
#
# 0: 384x640 4 persons, 156.3ms
# Speed: 2.7ms preprocess, 156.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_340.jpg
#
# 0: 384x640 4 persons, 102.4ms
# Speed: 4.5ms preprocess, 102.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_341.jpg
#
# 0: 384x640 4 persons, 100.1ms
# Speed: 3.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_342.jpg
#
# 0: 384x640 4 persons, 95.4ms
# Speed: 4.5ms preprocess, 95.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_343.jpg
#
# 0: 384x640 4 persons, 98.6ms
# Speed: 1.0ms preprocess, 98.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_344.jpg
#
# 0: 384x640 4 persons, 474.0ms
# Speed: 9.1ms preprocess, 474.0ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_345.jpg
#
# 0: 384x640 4 persons, 175.1ms
# Speed: 6.1ms preprocess, 175.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_346.jpg
#
# 0: 384x640 4 persons, 169.5ms
# Speed: 4.0ms preprocess, 169.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_347.jpg
#
# 0: 384x640 4 persons, 126.1ms
# Speed: 4.0ms preprocess, 126.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_348.jpg
#
# 0: 384x640 4 persons, 106.1ms
# Speed: 0.0ms preprocess, 106.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_349.jpg
#
# 0: 384x640 4 persons, 125.0ms
# Speed: 0.0ms preprocess, 125.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_35.jpg
#
# 0: 384x640 4 persons, 117.2ms
# Speed: 3.5ms preprocess, 117.2ms inference, 8.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_36.jpg
#
# 0: 384x640 4 persons, 120.3ms
# Speed: 0.0ms preprocess, 120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_37.jpg
#
# 0: 384x640 4 persons, 103.1ms
# Speed: 0.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_38.jpg
#
# 0: 384x640 4 persons, 101.2ms
# Speed: 7.5ms preprocess, 101.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_39.jpg
#
# 0: 384x640 4 persons, 103.5ms
# Speed: 0.0ms preprocess, 103.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_4.jpg
#
# 0: 384x640 4 persons, 130.7ms
# Speed: 2.6ms preprocess, 130.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_40.jpg
#
# 0: 384x640 4 persons, 109.9ms
# Speed: 0.0ms preprocess, 109.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_41.jpg
#
# 0: 384x640 4 persons, 124.0ms
# Speed: 9.1ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_42.jpg
#
# 0: 384x640 4 persons, 105.5ms
# Speed: 4.5ms preprocess, 105.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_43.jpg
#
# 0: 384x640 4 persons, 101.3ms
# Speed: 0.0ms preprocess, 101.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_44.jpg
#
# 0: 384x640 4 persons, 145.9ms
# Speed: 8.5ms preprocess, 145.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_45.jpg
#
# 0: 384x640 4 persons, 100.9ms
# Speed: 8.0ms preprocess, 100.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_46.jpg
#
# 0: 384x640 4 persons, 108.8ms
# Speed: 0.0ms preprocess, 108.8ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_47.jpg
#
# 0: 384x640 4 persons, 101.0ms
# Speed: 0.0ms preprocess, 101.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_48.jpg
#
# 0: 384x640 4 persons, 103.0ms
# Speed: 0.0ms preprocess, 103.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_49.jpg
#
# 0: 384x640 4 persons, 90.8ms
# Speed: 6.0ms preprocess, 90.8ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_5.jpg
#
# 0: 384x640 4 persons, 111.9ms
# Speed: 8.0ms preprocess, 111.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_50.jpg
#
# 0: 384x640 4 persons, 117.5ms
# Speed: 6.5ms preprocess, 117.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_51.jpg
#
# 0: 384x640 4 persons, 111.3ms
# Speed: 1.0ms preprocess, 111.3ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_52.jpg
#
# 0: 384x640 4 persons, 101.3ms
# Speed: 4.0ms preprocess, 101.3ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_53.jpg
#
# 0: 384x640 4 persons, 120.4ms
# Speed: 0.0ms preprocess, 120.4ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_54.jpg
#
# 0: 384x640 4 persons, 122.3ms
# Speed: 0.0ms preprocess, 122.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_55.jpg
#
# 0: 384x640 4 persons, 97.0ms
# Speed: 10.4ms preprocess, 97.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_56.jpg
#
# 0: 384x640 4 persons, 120.1ms
# Speed: 0.0ms preprocess, 120.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_57.jpg
#
# 0: 384x640 4 persons, 106.1ms
# Speed: 5.1ms preprocess, 106.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_58.jpg
#
# 0: 384x640 4 persons, 124.0ms
# Speed: 7.2ms preprocess, 124.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_59.jpg
#
# 0: 384x640 4 persons, 105.2ms
# Speed: 8.1ms preprocess, 105.2ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_6.jpg
#
# 0: 384x640 4 persons, 103.7ms
# Speed: 0.0ms preprocess, 103.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_60.jpg
#
# 0: 384x640 4 persons, 110.2ms
# Speed: 0.0ms preprocess, 110.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_61.jpg
#
# 0: 384x640 4 persons, 99.9ms
# Speed: 1.8ms preprocess, 99.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_62.jpg
#
# 0: 384x640 4 persons, 94.9ms
# Speed: 1.0ms preprocess, 94.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_63.jpg
#
# 0: 384x640 4 persons, 97.8ms
# Speed: 11.5ms preprocess, 97.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_64.jpg
#
# 0: 384x640 4 persons, 128.7ms
# Speed: 0.0ms preprocess, 128.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_65.jpg
#
# 0: 384x640 4 persons, 124.1ms
# Speed: 7.5ms preprocess, 124.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_66.jpg
#
# 0: 384x640 4 persons, 128.8ms
# Speed: 2.2ms preprocess, 128.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_67.jpg
#
# 0: 384x640 4 persons, 104.5ms
# Speed: 4.5ms preprocess, 104.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_68.jpg
#
# 0: 384x640 4 persons, 149.1ms
# Speed: 3.6ms preprocess, 149.1ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_69.jpg
#
# 0: 384x640 4 persons, 124.8ms
# Speed: 8.0ms preprocess, 124.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_7.jpg
#
# 0: 384x640 4 persons, 109.0ms
# Speed: 10.9ms preprocess, 109.0ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_70.jpg
#
# 0: 384x640 4 persons, 156.7ms
# Speed: 3.0ms preprocess, 156.7ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_71.jpg
#
# 0: 384x640 4 persons, 129.5ms
# Speed: 10.4ms preprocess, 129.5ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_72.jpg
#
# 0: 384x640 4 persons, 130.8ms
# Speed: 9.1ms preprocess, 130.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_73.jpg
#
# 0: 384x640 4 persons, 152.1ms
# Speed: 1.0ms preprocess, 152.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_74.jpg
#
# 0: 384x640 4 persons, 119.7ms
# Speed: 2.3ms preprocess, 119.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_75.jpg
#
# 0: 384x640 4 persons, 160.1ms
# Speed: 4.0ms preprocess, 160.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_76.jpg
#
# 0: 384x640 4 persons, 122.9ms
# Speed: 0.0ms preprocess, 122.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_77.jpg
#
# 0: 384x640 4 persons, 100.9ms
# Speed: 10.0ms preprocess, 100.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_78.jpg
#
# 0: 384x640 4 persons, 104.1ms
# Speed: 9.0ms preprocess, 104.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_79.jpg
#
# 0: 384x640 4 persons, 126.8ms
# Speed: 0.0ms preprocess, 126.8ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_8.jpg
#
# 0: 384x640 4 persons, 91.0ms
# Speed: 4.6ms preprocess, 91.0ms inference, 8.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_80.jpg
#
# 0: 384x640 4 persons, 104.1ms
# Speed: 0.0ms preprocess, 104.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_81.jpg
#
# 0: 384x640 4 persons, 112.6ms
# Speed: 2.3ms preprocess, 112.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_82.jpg
#
# 0: 384x640 4 persons, 119.8ms
# Speed: 1.2ms preprocess, 119.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_83.jpg
#
# 0: 384x640 4 persons, 119.0ms
# Speed: 0.0ms preprocess, 119.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_84.jpg
#
# 0: 384x640 4 persons, 154.7ms
# Speed: 0.0ms preprocess, 154.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_85.jpg
#
# 0: 384x640 4 persons, 150.0ms
# Speed: 58.8ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_86.jpg
#
# 0: 384x640 4 persons, 103.1ms
# Speed: 0.0ms preprocess, 103.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_87.jpg
#
# 0: 384x640 4 persons, 101.5ms
# Speed: 0.5ms preprocess, 101.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_88.jpg
#
# 0: 384x640 4 persons, 113.9ms
# Speed: 5.9ms preprocess, 113.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_89.jpg
#
# 0: 384x640 4 persons, 101.7ms
# Speed: 9.8ms preprocess, 101.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_9.jpg
#
# 0: 384x640 4 persons, 122.0ms
# Speed: 4.1ms preprocess, 122.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_90.jpg
#
# 0: 384x640 4 persons, 130.1ms
# Speed: 1.7ms preprocess, 130.1ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_91.jpg
#
# 0: 384x640 4 persons, 134.1ms
# Speed: 0.0ms preprocess, 134.1ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_92.jpg
#
# 0: 384x640 4 persons, 144.9ms
# Speed: 5.2ms preprocess, 144.9ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_93.jpg
#
# 0: 384x640 4 persons, 110.1ms
# Speed: 9.6ms preprocess, 110.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_94.jpg
#
# 0: 384x640 4 persons, 133.0ms
# Speed: 1.2ms preprocess, 133.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_95.jpg
#
# 0: 384x640 4 persons, 131.0ms
# Speed: 0.0ms preprocess, 131.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_96.jpg
#
# 0: 384x640 4 persons, 120.1ms
# Speed: 8.6ms preprocess, 120.1ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_97.jpg
#
# 0: 384x640 4 persons, 100.1ms
# Speed: 0.0ms preprocess, 100.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_98.jpg
#
# 0: 384x640 4 persons, 130.2ms
# Speed: 9.9ms preprocess, 130.2ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed and saved labels for: img_99.jpg
